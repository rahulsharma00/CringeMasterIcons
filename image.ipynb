# %%
import google.generativeai as genai

# %%
import PIL.Image

img = PIL.Image.open('test.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x960>

# %%
model = genai.GenerativeModel('gemini-pro-vision')

# %%
response = model.generate_content(img)

(response.text)
# Out:
# ' The photo shows a hand holding an iPhone 13 Pro in the rain. The phone is wet from the rain.'
